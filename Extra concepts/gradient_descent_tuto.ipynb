# %%
import numpy as np

# %% [markdown]
# Lets find the minimun of the function $J=w^2$ using gradient descent

# %%
w = 20

# %% [markdown]
# It's derivative is $\frac{d J} {d w}=2w$, using $w\leftarrow w - \eta \nabla_w J $, $\eta$ is the learning rate.
#
# We have in code:

# %%
for i in range(30):
    w=w-0.1*2*w
    print(w)
# Out:
# 16.0
# 12.8
# 10.24
# 8.192
# 6.5536
# 5.24288
# 4.194304000000001
# 3.3554432000000007
# 2.6843545600000005
# 2.1474836480000006
# 1.7179869184000005
# 1.3743895347200004
# 1.0995116277760002
# 0.8796093022208001
# 0.7036874417766401
# 0.562949953421312
# 0.45035996273704965
# 0.3602879701896397
# 0.28823037615171176
# 0.23058430092136942
# 0.18446744073709553
# 0.14757395258967643
# 0.11805916207174114
# 0.09444732965739291
# 0.07555786372591433
# 0.06044629098073147
# 0.048357032784585176
# 0.03868562622766814
# 0.030948500982134513
# 0.02475880078570761

# %% [markdown]
# 30 setps is not close enough

# %%
w=20
for i in range(100):
    w= w-0.1*2*w
    print(w)
# Out:
# 16.0
# 12.8
# 10.24
# 8.192
# 6.5536
# 5.24288
# 4.194304000000001
# 3.3554432000000007
# 2.6843545600000005
# 2.1474836480000006
# 1.7179869184000005
# 1.3743895347200004
# 1.0995116277760002
# 0.8796093022208001
# 0.7036874417766401
# 0.562949953421312
# 0.45035996273704965
# 0.3602879701896397
# 0.28823037615171176
# 0.23058430092136942
# 0.18446744073709553
# 0.14757395258967643
# 0.11805916207174114
# 0.09444732965739291
# 0.07555786372591433
# 0.06044629098073147
# 0.048357032784585176
# 0.03868562622766814
# 0.030948500982134513
# 0.02475880078570761
# 0.01980704062856609
# 0.015845632502852872
# 0.012676506002282298
# 0.01014120480182584
# 0.008112963841460671
# 0.006490371073168537
# 0.00519229685853483
# 0.004153837486827864
# 0.0033230699894622913
# 0.002658455991569833
# 0.002126764793255866
# 0.001701411834604693
# 0.0013611294676837543
# 0.0010889035741470034
# 0.0008711228593176028
# 0.0006968982874540822
# 0.0005575186299632657
# 0.00044601490397061256
# ...

# %% [markdown]
# This is more close to zero

# %% [markdown]
# Now let's make another example let's use $J(w_1,w_2)=w_1^2+w_2^4$:
#
# It's derivative is $\nabla_{w_i}J(w_1,w_2)=2w_1+4w_2^3$
#
# This in code is:

# %%
w_1=30
w_2=1

for i in range(100):
    w_1=w_1-0.1*2*w_1
    w_2 = w_2 -0.1*4*w_2**3
    print(w_1,w_2)
    J = w_1**2 + w_2**4
# Out:
# 24.0 0.6
# 19.2 0.5136
# 15.36 0.4594080178176
# 12.288 0.4206237405718542
# 9.830400000000001 0.3908563109881773
# 7.864320000000001 0.3669720736857909
# 6.291456000000001 0.3472042417831423
# 5.033164800000001 0.3304619441510911
# 4.0265318400000005 0.31602669274660644
# 3.2212254720000004 0.30340169555933166
# 2.5769803776000004 0.2922301309420271
# 2.0615843020800004 0.282247730918311
# 1.6492674416640003 0.27325376228015863
# 1.3194139533312002 0.26509247919895007
# 1.0555311626649602 0.25764083325687426
# 0.8444249301319682 0.25080007762688267
# 0.6755399441055745 0.24448987956274412
# 0.5404319552844596 0.23864409708541667
# 0.4323455642275677 0.23320768861184732
# 0.34587645138205414 0.22813441149938277
# 0.2767011611056433 0.2233850810585697
# 0.22136092888451464 0.21892623491886065
# 0.17708874310761172 0.21472909530551876
# 0.14167099448608939 0.21076875346242105
# 0.11333679558887151 0.2070235219200267
# 0.09066943647109721 0.2034744151136851
# ...

# %% [markdown]
# Thety both begin to get close to zero, the inimun of J function
