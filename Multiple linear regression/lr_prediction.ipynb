# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('scrap price.csv')

df.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
# 2    hatchback         rwd          front       94.5  ...         152
# 3        sedan         fwd          front       99.8  ...         109
# 4        sedan         4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
#We will select a few of the 26 columns enginesize, carbody, horsepower, price

Y=np.array(df[['price']])
X1=np.array(df[['enginesize']])
X2 = np.array(df[['horsepower']])

# %%
X=np.concatenate([X1, X2],axis=1)
print(X)
# Out:
# [[130 111]
#  [130 111]
#  [152 154]
#  [109 102]
#  [136 115]
#  [136 110]
#  [136 110]
#  [136 110]
#  [131 140]
#  [131 160]
#  [108 101]
#  [108 101]
#  [164 121]
#  [164 121]
#  [164 121]
#  [209 182]
#  [209 182]
#  [209 182]
#  [ 61  48]
#  [ 90  70]
#  [ 90  70]
#  [ 90  68]
#  [ 90  68]
#  [ 98 102]
#  [ 90  68]
#  [ 90  68]
#  [ 90  68]
#  [ 98 102]
#  [122  88]
#  [156 145]
#  [ 92  58]
#  [ 92  76]
#  [ 79  60]
#  [ 92  76]
#  [ 92  76]
#  [ 92  76]
#  [ 92  76]
#  [110  86]
#  [110  86]
#  [110  86]
#  [110  86]
#  [110 101]
#  [110 100]
#  [111  78]
#  [ 90  70]
#  [ 90  70]
#  [119  90]
#  [258 176]
#  [258 176]
#  [326 262]
#  [ 91  68]
#  [ 91  68]
#  [ 91  68]
#  [ 91  68]
#  [ 91  68]
#  [ 70 101]
#  [ 70 101]
#  [ 70 101]
#  [ 80 135]
#  [122  84]
#  [122  84]
#  [122  84]
#  [122  84]
#  [122  64]
#  [122  84]
#  [140 120]
#  [134  72]
#  [183 123]
#  [183 123]
#  [183 123]
#  [183 123]
#  [234 155]
#  [234 155]
#  [308 184]
#  [304 184]
#  [140 175]
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter(X[:,0],X[:,1],1)
plt.show()

# %%
#Calculate the weights 
w = np.linalg.solve(np.dot(X.T, X), np.dot(X.T,Y))

Y_pred = np.dot(X,w)

# %%
d1 = Y - Y_pred

d2 = Y - Y.mean()

r2= 1- d1[:,0].dot(d1[:,0])/d2[:,0].dot(d2[:,0])

print(f"The r-squared is {r2}")
# Out:
# The r-squared is 0.6869035230422724

# %% [markdown]
# Therefore the linear regression needs more variables or choose better ones
